# %%
import pandas as pd
from file_paths_and_consts import *
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error
import datetime
from matplotlib import rcParams
from matplotlib.colors import LinearSegmentedColormap
plt.style.use('classic')
import seaborn as sns
import geopandas as gpd
import random
sns.set()
import os
SEED_VALUE = 590
random.seed(SEED_VALUE)

OUTPUT_DIR
# Out:
# '/project/biocomplexity/UKR_forecast/migration_data/AAMAS_output_data/'

# %%
import multiprocessing as mp
import numpy as np
def calc_attitude_parallel(num):
    return num**2,num**3

def multiproc_attitude(all_nums):
    cpus = 4#mp.cpu_count()
    #st_time = time.time()
    hh_splits = np.array_split(all_nums, cpus) #--this a list with multiple dataframe.. each dataframe is used by one core
    #print(hh_splits)
    pool_args = [h_chunk for h_idx,h_chunk in enumerate(hh_splits)]
    #print('total time taken to split',time.time()-st_time)
    pool = mp.Pool(processes = cpus)
    results = pool.map(calc_attitude_parallel, pool_args)
    pool.close()
    pool.join()
    return results

ss = []

for i in range(0,100):
    ss.append(i)
    
results = multiproc_attitude(ss)
print(type(results[0][1]))
# Out:
# <class 'numpy.ndarray'>

# %%
pd.__version__
# Out:
# '1.1.0'

# %%
ROLLING = 12
conflict_data_file = UNCLEANED_DATA_DIR+'ukraine_conflict_data_feb_oct.csv'
refugee_data_file = GROUND_TRUTH_DIR+'ukraine_refugee_data_2.csv'
geo_shp_file = UNCLEANED_DATA_DIR+'UKR_shapefile_2/ukr_shp/ukr_admbnda_adm2_sspe_20230201.shp'

conflict_data = pd.read_csv(conflict_data_file)
conflict_data['time'] = pd.to_datetime(conflict_data['event_date'])
conflict_data = conflict_data.sort_values(by='time')
conflict_count = conflict_data[['time','fatalities']].groupby('time')['fatalities'].count().reset_index()
conflict_count['fatalities'] = conflict_count['fatalities'].cumsum()
conflict_count['fatalities'] = conflict_count['fatalities'].rolling(ROLLING).mean()
conflict_count = conflict_count.dropna(subset=['fatalities'])

refugee_data = pd.read_csv(refugee_data_file)
refugee_data['time'] = pd.to_datetime(refugee_data['time'])
refugee_data = refugee_data.sort_values(by='time')
refugee_data['refugee'] = refugee_data['refugee'].rolling(ROLLING).mean()
refugee_data = refugee_data.dropna(subset=['refugee'])
# refugee_data['refugee'] = refugee_data['refugee'].diff()
# refugee_data = refugee_data.dropna(subset=['refugee'])

burundi_gdf = gpd.read_file(geo_shp_file)

fig,ax = plt.subplots(1,2,figsize=(15,5),gridspec_kw={'width_ratios': [2, 1]})
plt.xticks(rotation=60)
rcParams["font.family"] = "calibri"
rcParams["font.size"] = 12
rcParams["axes.labelsize"] = 16
rcParams["axes.titlesize"] = 20
rcParams["xtick.labelsize"] = 14
rcParams["ytick.labelsize"] = 14

ax2 = ax[0].twinx()
ax2.plot(refugee_data['time'],refugee_data['refugee'],marker='X',linewidth=2,color='green',label='Observed Refugee')
ax[0].plot(conflict_count['time'],conflict_count['fatalities'],marker='o',linewidth=2,label='# Daily Events')
ax[0].set_xlim([datetime.date(2022, 2, 24), datetime.date(2022, 5, 31)])
#ax.set_ylim([conflict_count['fatalities'].min()-5,conflict_count['fatalities'].max()+5])
#ax2.set_ylim([refugee_data['refugee'].min()-500,refugee_data['refugee'].max()+500])
YLIM = [0,1000]
ax[0].legend(loc='upper left')
ax2.legend(loc='lower right')
#ax[0].set_ylim(YLIM)
fig.tight_layout()

burundi_gdf.plot(ax=ax[1],color='blue',alpha=0.2)
EPS = 0.1
SCALE = 2
conflict_data_gdf = gpd.GeoDataFrame(conflict_data,geometry=gpd.points_from_xy(conflict_data.longitude,conflict_data.latitude))
conflict_data_gdf.plot(ax=ax[1],color='red',alpha=0.2,markersize=(conflict_data['fatalities']+EPS)*SCALE)
ax[1].set_xlim(burundi_gdf.total_bounds[0], burundi_gdf.total_bounds[2])
ax[1].set_ylim(burundi_gdf.total_bounds[1], burundi_gdf.total_bounds[3])
fig.tight_layout()

# %%
all_ids = burundi_gdf['ADM2_EN'].tolist()

# %%
def get_results_for_2(hyper_comb, who='refugee',region_name=["all"],prefix='fresh_calib_batch_simulation',look_until=100,ROLL=7,partition = 40,scale_1 = 0.5,scale_2 = 2):
    search_in_ids = all_ids
    if region_name!=["all"]:
        search_in_ids = region_name
    
    all_dfs = []
    found = 0
    for cur_id in search_in_ids:
        #print(cur_id)
        f_name = prefix+'_completed_'+str(cur_id)+'_'+str(hyper_comb).zfill(5)+'.csv'
        f2_name = prefix+'_'+str(cur_id)+'_'+str(hyper_comb).zfill(5)+'.csv'
        #print(f_name)
        if os.path.isfile(OUTPUT_DIR+f_name):
            true_f_name = f_name
        elif os.path.isfile(OUTPUT_DIR+f2_name):
            true_f_name = f2_name
        else:
            #print(cur_id,'not found')
            continue
            
        cur_df = pd.read_csv(OUTPUT_DIR+true_f_name)
        cur_df['time'] = pd.to_datetime(cur_df['time'])
        all_dfs.append(cur_df)
        found = found + 1
    
    ovr_df = pd.concat(all_dfs)
    ovr_df = ovr_df.groupby('time')[who].sum().reset_index()
    scale_list = [scale_1]*partition+[scale_2]*(ovr_df.shape[0]-partition)
    ovr_df['scale'] = scale_list
    ovr_df[who] = ovr_df[who]*ovr_df['scale']
    ovr_df[who] = ovr_df[who].rolling(ROLL).mean()
    #print(ovr_df.columns.tolist())
    ovr_df = ovr_df.dropna(subset=[who])
    print(found,'raions found')
    return ovr_df

def get_results_for_state(hyper_comb, who='refugee',region_name=["all"],prefix='fresh_calib_batch_simulation',look_until=100,ROLL=7,IDP_REFUGEE_PROB=0.1,partition = 40,scale_1 = 0.5,scale_2 = 2):
    OUTPUT_DIR_OLD = BASE_DIR+'output_data/' 
    search_in_ids = all_ids
    if region_name!=["all"]:
        search_in_ids = region_name
    
    all_dfs = []
    found = 0
    for cur_id in search_in_ids:
        #print(cur_id)
        f_name = prefix+'_completed_'+str(cur_id)+'_'+str(hyper_comb).zfill(5)+'.csv'
        f2_name = prefix+'_'+str(cur_id)+'_'+str(hyper_comb).zfill(5)+'.csv'
        #print(f_name)
        if os.path.isfile(OUTPUT_DIR_OLD+f_name):
            true_f_name = f_name
        elif os.path.isfile(OUTPUT_DIR_OLD+f2_name):
            true_f_name = f2_name
        else:
            continue
            
        cur_df = pd.read_csv(OUTPUT_DIR_OLD+true_f_name)
        cur_df['time'] = pd.to_datetime(cur_df['time'])
        all_dfs.append(cur_df)
        found = found + 1
    
    ovr_df = pd.concat(all_dfs)
    ovr_df = ovr_df.groupby('time')['refugee'].sum().reset_index()
    
    #adjustment
    BORDER_CROSS_PROB = float(np.random.normal(0.32,0.02,1)[0])
    IDP_PROB = 1.0 - BORDER_CROSS_PROB
    #IDP_REFUGEE_PROB = 0.1
    ovr_df['FD'] = ovr_df['refugee']/BORDER_CROSS_PROB
    ovr_df['IDP'] = ovr_df['FD']*IDP_PROB
    
    f_list = ovr_df['FD'].tolist()
    r_list = ovr_df['refugee'].tolist()
    i_list = ovr_df['IDP'].tolist()
    
    for i in range(1,len(f_list)):
        i_list[i] = f_list[i]*IDP_PROB + i_list[i-1]*(1-IDP_REFUGEE_PROB)
    for i in range(1,len(f_list)):
        r_list[i] = f_list[i]*BORDER_CROSS_PROB + i_list[i-1]*(IDP_REFUGEE_PROB)
    
    ovr_df['refugee'] = r_list
    
    scale_list = [scale_1]*partition+[scale_2]*(ovr_df.shape[0]-partition)
    ovr_df['scale'] = scale_list
    ovr_df[who] = ovr_df[who]*ovr_df['scale']
    
    ovr_df[who] = ovr_df[who].rolling(ROLL).mean()
    #print(ovr_df.columns.tolist())
    ovr_df = ovr_df.dropna(subset=[who])
    print(found,'raions found')
    return ovr_df


def get_raion_list(hyper_comb, who='refugee',region_name=["all"],prefix='fresh_calib_batch_simulation',look_until=100,ROLL=7):
    
    search_in_ids = all_ids
    if region_name!=["all"]:
        search_in_ids = region_name
    
    all_dfs = []
    found = 0
    for cur_id in search_in_ids:
        #print(cur_id)
        f_name = prefix+'_completed_'+str(cur_id)+'_'+str(hyper_comb).zfill(5)+'.csv'
        #print(f_name)
        if os.path.isfile(OUTPUT_DIR+f_name):
            true_f_name = f_name
            all_dfs.append(cur_id)
        else:
            continue
            
    return set(all_dfs)

#get_results_for(777,prefix='mim')
def get_uncertainty_results(hyper_comb, region_name="all",prefix='fresh_calib_batch_simulation'):
    all_dfs = []
    if region_name=="all":
        col_to_sum = ['refugee','old_people','child','male','female']
        for cur_id in all_ids:
            f_name = prefix+'_result_completed_'+str(cur_id)+'_'+str(hyper_comb).zfill(5)+'.csv'
            if os.path.isfile(OUTPUT_DIR+f_name):
                cur_df = pd.read_csv(OUTPUT_DIR+f_name)
                cur_df['time'] = pd.to_datetime(cur_df['time'])
                cur_df = cur_df.sort_values(by=['time','refugee'],ascending=[True,False])
                
                cur_df = cur_df.drop_duplicates(subset=['time'],keep='first')
                all_dfs.append(cur_df)
    return all_dfs

# %%
# ## compare if result looks same for a raion against two runs
# df1 = get_results_for_2(99950,region_name=['Kyiv'],prefix='mim_result')
# df2 = get_results_for_2(99969,region_name=['Kyiv'],prefix='mim_result')

# rcParams["font.family"] = "calibri"
# rcParams["font.size"] = 32
# rcParams["axes.labelsize"] = 28
# rcParams["axes.titlesize"] = 28
# rcParams["xtick.labelsize"] = 26
# rcParams["ytick.labelsize"] = 26

# fig,ax = plt.subplots(figsize=(14,5))
# plt.xticks(rotation=30)

# ax.plot(df1['time'],df1['refugee'],label='99950')
# ax.plot(df2['time'],df2['refugee'],label='99960')

# ax.set_xlim([datetime.date(2022, 3, 7), datetime.date(2022, 5, 6)])
# ax.legend(loc='best')
# df1['refugee'].corr(df2['refugee'])

# %%
macro_name = 'West'
#center - 2022-04-21
# south - 2022-03-22
# east - 2022-03-21
# north - 2022-03-15
# west = 2022-04-05

idp_df = pd.read_csv('ukr_idp_macro.csv')
particular_df = idp_df[idp_df.macro_region==macro_name]
particular_df['idp'] = particular_df['idp'].diff()
particular_df = particular_df.dropna(subset=['idp'])
particular_df['time'] = pd.to_datetime(particular_df['date'])
particular_df = particular_df.sort_values(by='time')
particular_df['idp'] = particular_df['idp'].rolling(ROLLING).mean()
particular_df = particular_df.dropna(subset=['idp'])
particular_df
# Out:
# /home/zm8bh/.conda/envs/biocomplexity/lib/python3.7/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
#            date macro_region           idp       time
# 397  2022-03-20         West  99034.635520 2022-03-20
# 398  2022-03-21         West  82568.327184 2022-03-21
# 399  2022-03-22         West  68182.386609 2022-03-22
# 400  2022-03-23         West  55867.484531 2022-03-23
# 401  2022-03-24         West  45612.764676 2022-03-24
# ..          ...          ...           ...        ...
# 457  2022-05-19         West -53100.000000 2022-05-19
# 458  2022-05-20         West -58258.972437 2022-05-20
# 459  2022-05-21         West -63417.944875 2022-05-21
# 460  2022-05-22         West -68576.917312 2022-05-22
# 461  2022-05-23         West -73735.889750 2022-05-23
#
# [65 rows x 4 columns]

# %%
idp_macro_map = pd.read_csv('idp_macro.csv')
entire_gdf_ukr = burundi_gdf[['ADM2_EN','ADM1_EN','geometry']].merge(idp_macro_map,left_on='ADM1_EN',right_on='Oblast',how='inner')
raion_list = entire_gdf_ukr[entire_gdf_ukr['Macro-region']==macro_name]['ADM2_EN'].tolist()
raion_list
# Out:
# ['Volodymyrskyi',
#  'Kamin-Kashyrskyi',
#  'Kovelskyi',
#  'Lutskyi',
#  'Berehivskyi',
#  'Mukachivskyi',
#  'Rakhivskyi',
#  'Tiachivskyi',
#  'Uzhhorodskyi',
#  'Khustskyi',
#  'Verkhovynskyi',
#  'Ivano-Frankivskyi',
#  'Kaluskyi',
#  'Kolomyiskyi',
#  'Kosivskyi',
#  'Nadvirnianskyi',
#  'Drohobytskyi',
#  'Zolochivskyi',
#  'Lvivskyi',
#  'Sambirskyi',
#  'Stryiskyi',
#  'Chervonohradskyi',
#  'Yavorivskyi',
#  'Varaskyi',
#  'Dubenskyi',
#  'Rivnenskyi',
#  'Sarnenskyi',
#  'Kremenetskyi',
#  'Ternopilskyi',
#  'Chortkivskyi',
#  'Kamianets-Podilskyi',
#  'Khmelnytskyi',
#  'Shepetivskyi',
#  'Vyzhnytskyi',
#  'Dnistrovskyi',
#  'Chernivetskyi']

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error

plt.style.use('classic')
import seaborn as sns
sns.set()

def get_uncertainty(sim_indices,first_df,q1=0.25,q3=0.75):
    #first_df = first_df[0:sz]
    run_cols = [str(i) for i in sim_indices if str(i) in first_df.columns.tolist()]
    medians = first_df[run_cols].median(axis=1)
    q1 = first_df[run_cols].quantile(q1, axis=1)
    q3 = first_df[run_cols].quantile(q3, axis=1)
    return medians,q1,q3

# %%
# #second_df = []

# for vv in simulation_indices_state:
#     print(vv,end=' ')
#     current_df = get_results_for_state(vv,prefix='mim_result',ROLL=7,IDP_REFUGEE_PROB=0.2,partition=40,scale_1=0.7,scale_2=0.5)
#     current_df['comb'] = str(vv)
#     #current_df_unsmoothed = get_results_for(vv,prefix='mim_result',ROLL=1)
#     #current_df_unsmoothed['comb'] = str(vv)

#     first_df_state.append(current_df)
#     #second_df.append(current_df_unsmoothed)
# first_df_state = pd.concat(first_df_state).pivot(index='time',columns='comb',values='refugee').reset_index().fillna(0)
# #print(first_df.head())
# # mm = 1.5
# # ss = 38
# # for col in simulation_indices:
# #     first_df[str(col)][ss:] = first_df[str(col)][ss:]*mm
#     #print(first_df.head())
# #second_df = pd.concat(second_df).pivot(index='time',columns='comb',values='refugee').reset_index().fillna(0)

# %%
# %%time
import warnings
warnings.filterwarnings('ignore')

macro_regions = []
first_dfs = []
first_df_states = []

simulation_indices = [i for i in range(20000,20000+100)]
simulation_indices_state = [80000+i for i in range(9,18)]


for macro_name in ['Kyiv','Center','West','East','North','South']:
    
    print(macro_name)
    
    raion_list = entire_gdf_ukr[entire_gdf_ukr['Macro-region']==macro_name]['ADM2_EN'].tolist()
    
    first_df = []
    second_df = []

    for vv in simulation_indices:
        try:
            print(vv,end=' ')
            current_df = get_results_for_2(vv,region_name=raion_list,prefix='mim_result',ROLL=ROLLING,partition=42,scale_1=1.0*1.2*(0.68/0.32),scale_2=2.0*1.4*(0.68/0.32))
            current_df['comb'] = str(vv)
            first_df.append(current_df)
        except:
            continue

    first_df = pd.concat(first_df).pivot(index='time',columns='comb',values='refugee').reset_index().fillna(0)
    macro_regions.append(macro_name)
    first_dfs.append(first_df)
    
    first_df_state = []
    
    for vv in simulation_indices_state:
        try:
            print(vv,end=' ')
            current_df = get_results_for_state(vv,region_name=raion_list,who='IDP',prefix='mim_result',ROLL=7,IDP_REFUGEE_PROB=0.2,partition=40,scale_1=0.7,scale_2=0.5)
            current_df['comb'] = str(vv)
            first_df_state.append(current_df)
        except:
            continue
    #second_df.append(current_df_unsmoothed)
    first_df_state = pd.concat(first_df_state).pivot(index='time',columns='comb',values='IDP').reset_index().fillna(0)
    first_df_states.append(first_df_state)
# Out:
# Kyiv
# 20000 1 raions found
# 20001 1 raions found
# 20002 1 raions found
# 20003 1 raions found
# 20004 1 raions found
# 20005 1 raions found
# 20006 1 raions found
# 20007 1 raions found
# 20008 1 raions found
# 20009 1 raions found
# 20010 1 raions found
# 20011 1 raions found
# 20012 1 raions found
# 20013 1 raions found
# 20014 1 raions found
# 20015 1 raions found
# 20016 1 raions found
# 20017 1 raions found
# 20018 1 raions found
# 20019 1 raions found
# 20020 1 raions found
# 20021 1 raions found
# 20022 1 raions found
# 20023 1 raions found
# 20024 1 raions found
# 20025 1 raions found
# 20026 1 raions found
# 20027 1 raions found
# 20028 1 raions found
# 20029 1 raions found
# 20030 1 raions found
# 20031 20032 1 raions found
# 20033 1 raions found
# 20034 1 raions found
# 20035 1 raions found
# 20036 1 raions found
# 20037 1 raions found
# 20038 1 raions found
# 20039 1 raions found
# 20040 1 raions found
# 20041 1 raions found
# 20042 1 raions found
# 20043 1 raions found
# 20044 1 raions found
# 20045 1 raions found
# 20046 1 raions found
# 20047 1 raions found
# 20048 1 raions found
# 20049 1 raions found
# 20050 1 raions found
# 20051 1 raions found
# 20052 1 raions found
# 20053 1 raions found
# 20054 1 raions found
# 20055 1 raions found
# 20056 1 raions found
# 20057 1 raions found
# 20058 1 raions found
# 20059 1 raions found
# 20060 1 raions found
# 20061 1 raions found
# 20062 1 raions found
# 20063 1 raions found
# 20064 1 raions found
# 20065 1 raions found
# 20066 1 raions found
# 20067 1 raions found
# 20068 1 raions found
# 20069 1 raions found
# 20070 1 raions found
# 20071 1 raions found
# 20072 1 raions found
# 20073 1 raions found
# 20074 1 raions found
# 20075 1 raions found
# 20076 1 raions found
# 20077 1 raions found
# 20078 1 raions found
# 20079 1 raions found
# 20080 1 raions found
# 20081 1 raions found
# 20082 1 raions found
# 20083 1 raions found
# 20084 1 raions found
# 20085 1 raions found
# 20086 1 raions found
# 20087 1 raions found
# 20088 1 raions found
# 20089 1 raions found
# 20090 1 raions found
# 20091 1 raions found
# 20092 1 raions found
# 20093 1 raions found
# 20094 1 raions found
# 20095 1 raions found
# 20096 1 raions found
# 20097 1 raions found
# 20098 1 raions found
# 20099 1 raions found
# 80009 1 raions found
# 80010 1 raions found
# 80011 1 raions found
# 80012 1 raions found
# 80013 80014 1 raions found
# 80015 1 raions found
# 80016 1 raions found
# 80017 1 raions found
# Center
# 20000 12 raions found
# 20001 12 raions found
# 20002 12 raions found
# 20003 12 raions found
# 20004 12 raions found
# 20005 12 raions found
# 20006 12 raions found
# 20007 12 raions found
# 20008 12 raions found
# 20009 12 raions found
# 20010 12 raions found
# 20011 12 raions found
# 20012 12 raions found
# 20013 12 raions found
# 20014 12 raions found
# 20015 12 raions found
# 20016 12 raions found
# 20017 12 raions found
# 20018 12 raions found
# 20019 12 raions found
# 20020 12 raions found
# 20021 12 raions found
# 20022 12 raions found
# 20023 12 raions found
# 20024 12 raions found
# 20025 12 raions found
# 20026 12 raions found
# 20027 12 raions found
# 20028 12 raions found
# 20029 12 raions found
# 20030 12 raions found
# 20031 12 raions found
# 20032 12 raions found
# 20033 12 raions found
# 20034 12 raions found
# 20035 12 raions found
# 20036 12 raions found
# 20037 12 raions found
# 20038 12 raions found
# 20039 12 raions found
# 20040 12 raions found
# 20041 12 raions found
# 20042 12 raions found
# 20043 12 raions found
# 20044 12 raions found
# 20045 12 raions found
# 20046 12 raions found
# 20047 12 raions found
# 20048 12 raions found
# 20049 12 raions found
# 20050 12 raions found
# 20051 12 raions found
# 20052 12 raions found
# 20053 12 raions found
# 20054 12 raions found
# 20055 12 raions found
# 20056 12 raions found
# 20057 12 raions found
# 20058 12 raions found
# 20059 12 raions found
# 20060 12 raions found
# 20061 12 raions found
# 20062 12 raions found
# 20063 12 raions found
# 20064 12 raions found
# 20065 12 raions found
# 20066 12 raions found
# 20067 12 raions found
# 20068 12 raions found
# 20069 12 raions found
# 20070 12 raions found
# 20071 12 raions found
# 20072 12 raions found
# 20073 12 raions found
# 20074 12 raions found
# 20075 12 raions found
# 20076 12 raions found
# 20077 12 raions found
# 20078 12 raions found
# 20079 12 raions found
# 20080 12 raions found
# 20081 12 raions found
# 20082 12 raions found
# 20083 12 raions found
# 20084 12 raions found
# 20085 12 raions found
# 20086 12 raions found
# 20087 12 raions found
# 20088 12 raions found
# 20089 12 raions found
# 20090 12 raions found
# 20091 12 raions found
# 20092 12 raions found
# 20093 12 raions found
# 20094 12 raions found
# 20095 12 raions found
# 20096 12 raions found
# 20097 12 raions found
# 20098 12 raions found
# 20099 12 raions found
# 80009 18 raions found
# 80010 18 raions found
# 80011 18 raions found
# 80012 18 raions found
# 80013 18 raions found
# 80014 17 raions found
# 80015 18 raions found
# 80016 18 raions found
# 80017 18 raions found
# West
# 20000 24 raions found
# 20001 25 raions found
# 20002 24 raions found
# 20003 24 raions found
# 20004 24 raions found
# 20005 24 raions found
# 20006 24 raions found
# 20007 24 raions found
# 20008 24 raions found
# 20009 24 raions found
# 20010 25 raions found
# 20011 25 raions found
# 20012 24 raions found
# 20013 24 raions found
# 20014 25 raions found
# 20015 24 raions found
# 20016 24 raions found
# 20017 24 raions found
# 20018 24 raions found
# 20019 24 raions found
# 20020 25 raions found
# 20021 25 raions found
# 20022 24 raions found
# 20023 25 raions found
# 20024 24 raions found
# 20025 24 raions found
# 20026 24 raions found
# 20027 25 raions found
# 20028 25 raions found
# 20029 25 raions found
# 20030 24 raions found
# 20031 24 raions found
# 20032 24 raions found
# 20033 24 raions found
# 20034 24 raions found
# 20035 24 raions found
# 20036 24 raions found
# 20037 24 raions found
# 20038 24 raions found
# 20039 25 raions found
# 20040 25 raions found
# 20041 25 raions found
# 20042 25 raions found
# 20043 24 raions found
# 20044 24 raions found
# 20045 24 raions found
# 20046 24 raions found
# 20047 24 raions found
# 20048 24 raions found
# 20049 24 raions found
# 20050 25 raions found
# 20051 24 raions found
# 20052 24 raions found
# 20053 24 raions found
# 20054 24 raions found
# 20055 25 raions found
# 20056 24 raions found
# 20057 25 raions found
# 20058 24 raions found
# 20059 24 raions found
# 20060 25 raions found
# 20061 25 raions found
# 20062 25 raions found
# 20063 24 raions found
# 20064 24 raions found
# 20065 24 raions found
# 20066 25 raions found
# 20067 24 raions found
# 20068 25 raions found
# 20069 24 raions found
# 20070 24 raions found
# 20071 24 raions found
# 20072 24 raions found
# 20073 24 raions found
# 20074 24 raions found
# 20075 24 raions found
# 20076 25 raions found
# 20077 24 raions found
# 20078 24 raions found
# 20079 24 raions found
# 20080 24 raions found
# 20081 25 raions found
# 20082 24 raions found
# 20083 24 raions found
# 20084 24 raions found
# 20085 24 raions found
# 20086 24 raions found
# 20087 24 raions found
# 20088 24 raions found
# 20089 24 raions found
# 20090 24 raions found
# 20091 25 raions found
# 20092 24 raions found
# 20093 25 raions found
# 20094 25 raions found
# 20095 24 raions found
# 20096 24 raions found
# 20097 25 raions found
# 20098 24 raions found
# 20099 24 raions found
# 80009 36 raions found
# 80010 36 raions found
# 80011 36 raions found
# 80012 36 raions found
# 80013 35 raions found
# 80014 36 raions found
# 80015 36 raions found
# 80016 36 raions found
# 80017 36 raions found
# East
# 20000 35 raions found
# 20001 35 raions found
# 20002 35 raions found
# 20003 35 raions found
# 20004 35 raions found
# 20005 35 raions found
# 20006 35 raions found
# 20007 35 raions found
# 20008 35 raions found
# 20009 35 raions found
# 20010 35 raions found
# 20011 35 raions found
# 20012 35 raions found
# 20013 35 raions found
# 20014 35 raions found
# 20015 35 raions found
# 20016 35 raions found
# 20017 35 raions found
# 20018 35 raions found
# 20019 35 raions found
# 20020 35 raions found
# 20021 35 raions found
# 20022 35 raions found
# 20023 35 raions found
# 20024 35 raions found
# 20025 35 raions found
# 20026 35 raions found
# 20027 35 raions found
# 20028 35 raions found
# 20029 35 raions found
# 20030 35 raions found
# 20031 35 raions found
# 20032 35 raions found
# 20033 35 raions found
# 20034 35 raions found
# 20035 35 raions found
# 20036 35 raions found
# 20037 35 raions found
# 20038 35 raions found
# 20039 35 raions found
# 20040 35 raions found
# 20041 35 raions found
# 20042 35 raions found
# 20043 35 raions found
# 20044 35 raions found
# 20045 35 raions found
# 20046 35 raions found
# 20047 35 raions found
# 20048 35 raions found
# 20049 35 raions found
# 20050 35 raions found
# 20051 35 raions found
# 20052 35 raions found
# 20053 35 raions found
# 20054 35 raions found
# 20055 35 raions found
# 20056 35 raions found
# 20057 35 raions found
# 20058 35 raions found
# 20059 35 raions found
# 20060 35 raions found
# 20061 35 raions found
# 20062 35 raions found
# 20063 35 raions found
# 20064 35 raions found
# 20065 35 raions found
# 20066 35 raions found
# 20067 35 raions found
# 20068 35 raions found
# 20069 35 raions found
# 20070 35 raions found
# 20071 35 raions found
# 20072 35 raions found
# 20073 35 raions found
# 20074 35 raions found
# 20075 35 raions found
# 20076 35 raions found
# 20077 35 raions found
# 20078 35 raions found
# 20079 35 raions found
# 20080 35 raions found
# 20081 35 raions found
# 20082 35 raions found
# 20083 35 raions found
# 20084 35 raions found
# 20085 35 raions found
# 20086 35 raions found
# 20087 35 raions found
# 20088 35 raions found
# 20089 35 raions found
# 20090 35 raions found
# 20091 35 raions found
# 20092 35 raions found
# 20093 35 raions found
# 20094 35 raions found
# 20095 35 raions found
# 20096 35 raions found
# 20097 35 raions found
# 20098 35 raions found
# 20099 35 raions found
# 80009 33 raions found
# 80010 32 raions found
# 80011 33 raions found
# 80012 32 raions found
# 80013 30 raions found
# 80014 32 raions found
# 80015 32 raions found
# 80016 33 raions found
# 80017 33 raions found
# North
# 20000 22 raions found
# 20001 22 raions found
# 20002 22 raions found
# 20003 22 raions found
# 20004 22 raions found
# 20005 22 raions found
# 20006 22 raions found
# 20007 22 raions found
# 20008 22 raions found
# 20009 22 raions found
# 20010 22 raions found
# 20011 22 raions found
# 20012 22 raions found
# 20013 22 raions found
# 20014 22 raions found
# 20015 22 raions found
# 20016 22 raions found
# 20017 22 raions found
# 20018 22 raions found
# 20019 22 raions found
# 20020 22 raions found
# 20021 22 raions found
# 20022 22 raions found
# 20023 22 raions found
# 20024 22 raions found
# 20025 22 raions found
# 20026 22 raions found
# 20027 22 raions found
# 20028 22 raions found
# 20029 22 raions found
# 20030 22 raions found
# 20031 22 raions found
# 20032 22 raions found
# 20033 22 raions found
# 20034 22 raions found
# 20035 22 raions found
# 20036 22 raions found
# 20037 22 raions found
# 20038 22 raions found
# 20039 22 raions found
# 20040 22 raions found
# 20041 22 raions found
# 20042 22 raions found
# 20043 22 raions found
# 20044 22 raions found
# 20045 22 raions found
# 20046 22 raions found
# 20047 22 raions found
# 20048 22 raions found
# 20049 22 raions found
# 20050 22 raions found
# 20051 22 raions found
# 20052 22 raions found
# 20053 22 raions found
# 20054 22 raions found
# 20055 22 raions found
# 20056 22 raions found
# 20057 22 raions found
# 20058 22 raions found
# 20059 22 raions found
# 20060 22 raions found
# 20061 22 raions found
# 20062 22 raions found
# 20063 22 raions found
# 20064 22 raions found
# 20065 22 raions found
# 20066 22 raions found
# 20067 22 raions found
# 20068 22 raions found
# 20069 22 raions found
# 20070 22 raions found
# 20071 22 raions found
# 20072 22 raions found
# 20073 22 raions found
# 20074 22 raions found
# 20075 22 raions found
# 20076 22 raions found
# 20077 22 raions found
# 20078 22 raions found
# 20079 22 raions found
# 20080 22 raions found
# 20081 22 raions found
# 20082 22 raions found
# 20083 22 raions found
# 20084 22 raions found
# 20085 22 raions found
# 20086 22 raions found
# 20087 22 raions found
# 20088 22 raions found
# 20089 22 raions found
# 20090 22 raions found
# 20091 22 raions found
# 20092 22 raions found
# 20093 22 raions found
# 20094 22 raions found
# 20095 22 raions found
# 20096 22 raions found
# 20097 22 raions found
# 20098 22 raions found
# 20099 22 raions found
# 80009 22 raions found
# 80010 22 raions found
# 80011 22 raions found
# 80012 22 raions found
# 80013 22 raions found
# 80014 21 raions found
# 80015 22 raions found
# 80016 22 raions found
# 80017 22 raions found
# South
# 20000 15 raions found
# 20001 15 raions found
# 20002 15 raions found
# 20003 15 raions found
# 20004 15 raions found
# 20005 15 raions found
# 20006 15 raions found
# 20007 15 raions found
# 20008 15 raions found
# 20009 15 raions found
# 20010 15 raions found
# 20011 15 raions found
# 20012 15 raions found
# 20013 15 raions found
# 20014 15 raions found
# 20015 15 raions found
# 20016 15 raions found
# 20017 15 raions found
# 20018 15 raions found
# 20019 15 raions found
# 20020 15 raions found
# 20021 15 raions found
# 20022 15 raions found
# 20023 15 raions found
# 20024 15 raions found
# 20025 15 raions found
# 20026 15 raions found
# 20027 15 raions found
# 20028 15 raions found
# 20029 15 raions found
# 20030 15 raions found
# 20031 15 raions found
# 20032 15 raions found
# 20033 15 raions found
# 20034 15 raions found
# 20035 15 raions found
# 20036 15 raions found
# 20037 15 raions found
# 20038 15 raions found
# 20039 15 raions found
# 20040 15 raions found
# 20041 15 raions found
# 20042 15 raions found
# 20043 15 raions found
# 20044 15 raions found
# 20045 15 raions found
# 20046 15 raions found
# 20047 15 raions found
# 20048 15 raions found
# 20049 15 raions found
# 20050 15 raions found
# 20051 15 raions found
# 20052 15 raions found
# 20053 15 raions found
# 20054 15 raions found
# 20055 15 raions found
# 20056 15 raions found
# 20057 15 raions found
# 20058 15 raions found
# 20059 15 raions found
# 20060 15 raions found
# 20061 15 raions found
# 20062 15 raions found
# 20063 15 raions found
# 20064 15 raions found
# 20065 15 raions found
# 20066 15 raions found
# 20067 15 raions found
# 20068 15 raions found
# 20069 15 raions found
# 20070 15 raions found
# 20071 15 raions found
# 20072 15 raions found
# 20073 15 raions found
# 20074 15 raions found
# 20075 15 raions found
# 20076 15 raions found
# 20077 15 raions found
# 20078 15 raions found
# 20079 15 raions found
# 20080 15 raions found
# 20081 15 raions found
# 20082 15 raions found
# 20083 15 raions found
# 20084 15 raions found
# 20085 15 raions found
# 20086 15 raions found
# 20087 15 raions found
# 20088 15 raions found
# 20089 15 raions found
# 20090 15 raions found
# 20091 15 raions found
# 20092 15 raions found
# 20093 15 raions found
# 20094 15 raions found
# 20095 15 raions found
# 20096 15 raions found
# 20097 15 raions found
# 20098 15 raions found
# 20099 15 raions found
# 80009 16 raions found
# 80010 16 raions found
# 80011 16 raions found
# 80012 16 raions found
# 80013 15 raions found
# 80014 16 raions found
# 80015 16 raions found
# 80016 16 raions found
# 80017 16 raions found
# CPU times: user 26.5 s, sys: 1.09 s, total: 27.6 s
# Wall time: 57.9 s

# %%
import datetime
import seaborn as sns
import datetime
from matplotlib import rcParams
from matplotlib.colors import LinearSegmentedColormap
import matplotlib.dates as mdates

# macro_regions = []
# first_dfs = []
# first_df_states = []

rcParams["font.family"] = "calibri"
rcParams["font.size"] = 32
rcParams["axes.labelsize"] = 28
rcParams["axes.titlesize"] = 28
rcParams["xtick.labelsize"] = 26
rcParams["ytick.labelsize"] = 26

trim = 7

for idx, macro_region in  enumerate(macro_regions):
    print(macro_region)
    #idp_df = pd.read_csv('ukr_idp_macro.csv')
    particular_df = idp_df[idp_df.macro_region==macro_region]
    particular_df['idp'] = particular_df['idp'].diff()
    particular_df = particular_df.dropna(subset=['idp'])
    particular_df['time'] = pd.to_datetime(particular_df['date'])
    particular_df = particular_df.sort_values(by='time')
    particular_df['idp'] = particular_df['idp'].rolling(ROLLING).mean()
    particular_df = particular_df.dropna(subset=['idp'])
    
    first_df = first_dfs[idx]
    first_df_state = first_df_states[idx]
    
    median_normal,q1_normal,q3_normal = get_uncertainty(simulation_indices,first_df,q1=0.35,q3=0.65)
    median_normal_state,q1_normal_state,q3_normal_state = get_uncertainty(simulation_indices_state,first_df_state,q1=0.35,q3=0.65)


    fig,ax = plt.subplots(figsize=(8,5))
    plt.xticks(rotation=15)

    ax.plot(particular_df['time'], particular_df['idp']/1000,label='Observed',linewidth=4,color='#006d2c')

    sns.set_style('white')
    SHIFT = -1
    ax.plot(first_df['time'][0:SHIFT],median_normal.shift(SHIFT)[0:SHIFT]/1000,linewidth=2,color='#6a51a3',alpha=1,label='ABM-NA')
    ax.fill_between(first_df["time"][0:SHIFT], q1_normal.shift(SHIFT)[0:SHIFT]/1000, q3_normal.shift(SHIFT)[0:SHIFT]/1000, color='#9e9ac8',alpha=0.8)
    ax.plot(first_df_state['time'],median_normal_state/1000,linewidth=2,color='#b35806',alpha=1,label='Pandey et al.')
    ax.fill_between(first_df_state['time'], q1_normal_state/1000, q3_normal_state/1000, color='#e08214',alpha=0.5)


    myFmt = mdates.DateFormatter('%m/%d')
    ax.xaxis.set_major_locator(mdates.WeekdayLocator(interval=2))
    ax.xaxis.set_major_formatter(myFmt)


    sns.set_style('whitegrid')

    ax.legend(loc='best',ncol=1,fontsize=18)
    ax.set_ylabel("# Refugee (K)",fontweight='bold')
    ax.set_xlim([datetime.date(2022, 3, 22), datetime.date(2022, 5, 22)])
    ax.set_title(macro_region)
    ax.grid(axis='x')
    #print(ax.get_xticks())
    fig.tight_layout()
#fig.savefig('../Figures/aamas_abm_result.pdf',dpi=350,bbox_inches='tight')
#5110 porjonto bhalo
# Out:
# Kyiv
# Center
# West
# East
# North
# South
